# %%
import pandas

# %%
import os.path as op

# %%
import mne

# %%
# Out:
# Collecting mne-bids[full]
#   Downloading mne_bids-0.10-py2.py3-none-any.whl (905 kB)
# Requirement already satisfied: setuptools in c:\users\irmak\anaconda3\lib\site-packages (from mne-bids[full]) (61.2.0)
# Requirement already satisfied: mne>=0.24 in c:\users\irmak\anaconda3\lib\site-packages (from mne-bids[full]) (1.0.3)
# Collecting importlib-resources
#   Downloading importlib_resources-5.9.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: jinja2 in c:\users\irmak\anaconda3\lib\site-packages (from mne-bids[full]) (2.11.3)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\irmak\anaconda3\lib\site-packages (from mne-bids[full]) (1.7.3)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\irmak\anaconda3\lib\site-packages (from mne-bids[full]) (1.21.5)
# Collecting EDFlib-Python>=1.0.6
#   Downloading EDFlib_Python-1.0.6-py3-none-any.whl (26 kB)
# Collecting pybv>=0.6
#   Downloading pybv-0.7.4-py3-none-any.whl (24 kB)
# Collecting pymatreader>=0.0.29
#   Downloading pymatreader-0.0.30-py3-none-any.whl (9.0 kB)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\irmak\anaconda3\lib\site-packages (from mne-bids[full]) (1.4.2)
# Collecting nibabel>=2.5
#   Downloading nibabel-4.0.1-py3-none-any.whl (3.3 MB)
# Requirement already satisfied: matplotlib>=3.1.0 in c:\users\irmak\anaconda3\lib\site-packages (from mne-bids[full]) (3.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\irmak\anaconda3\lib\site-packages (from matplotlib>=3.1.0->mne-bids[full]) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\irmak\anaconda3\lib\site-packages (from matplotlib>=3.1.0->mne-bids[full]) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\irmak\anaconda3\lib\site-packages (from matplotlib>=3.1.0->mne-bids[full]) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\irmak\anaconda3\lib\site-packages (from matplotlib>=3.1.0->mne-bids[full]) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\irmak\anaconda3\lib\site-packages (from matplotlib>=3.1.0->mne-bids[full]) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\irmak\anaconda3\lib\site-packages (from matplotlib>=3.1.0->mne-bids[full]) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\irmak\anaconda3\lib\site-packages (from matplotlib>=3.1.0->mne-bids[full]) (0.11.0)
# Requirement already satisfied: pooch>=1.5 in c:\users\irmak\anaconda3\lib\site-packages (from mne>=0.24->mne-bids[full]) (1.6.0)
# Requirement already satisfied: tqdm in c:\users\irmak\anaconda3\lib\site-packages (from mne>=0.24->mne-bids[full]) (4.64.0)
# Requirement already satisfied: decorator in c:\users\irmak\anaconda3\lib\site-packages (from mne>=0.24->mne-bids[full]) (5.1.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\irmak\anaconda3\lib\site-packages (from pandas>=0.24.0->mne-bids[full]) (2021.3)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\irmak\anaconda3\lib\site-packages (from pooch>=1.5->mne>=0.24->mne-bids[full]) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in c:\users\irmak\anaconda3\lib\site-packages (from pooch>=1.5->mne>=0.24->mne-bids[full]) (2.27.1)
# Requirement already satisfied: future in c:\users\irmak\anaconda3\lib\site-packages (from pymatreader>=0.0.29->mne-bids[full]) (0.18.2)
# Requirement already satisfied: h5py in c:\users\irmak\anaconda3\lib\site-packages (from pymatreader>=0.0.29->mne-bids[full]) (3.6.0)
# Collecting xmltodict
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Requirement already satisfied: six>=1.5 in c:\users\irmak\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.0->mne-bids[full]) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\irmak\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne>=0.24->mne-bids[full]) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\irmak\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne>=0.24->mne-bids[full]) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\irmak\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne>=0.24->mne-bids[full]) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\irmak\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne>=0.24->mne-bids[full]) (1.26.9)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\irmak\anaconda3\lib\site-packages (from importlib-resources->mne-bids[full]) (3.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\irmak\anaconda3\lib\site-packages (from jinja2->mne-bids[full]) (2.0.1)
# Requirement already satisfied: colorama in c:\users\irmak\anaconda3\lib\site-packages (from tqdm->mne>=0.24->mne-bids[full]) (0.4.4)
# Installing collected packages: xmltodict, importlib-resources, pymatreader, pybv, nibabel, mne-bids, EDFlib-Python
# Successfully installed EDFlib-Python-1.0.6 importlib-resources-5.9.0 mne-bids-0.10 nibabel-4.0.1 pybv-0.7.4 pymatreader-0.0.30 xmltodict-0.13.0
#   WARNING: The scripts nib-conform.exe, nib-convert.exe, nib-dicomfs.exe, nib-diff.exe, nib-ls.exe, nib-nifti-dx.exe, nib-roi.exe, nib-stats.exe, nib-tck2trk.exe, nib-trk2tck.exe and parrec2nii.exe are installed in 'C:\Users\irmak\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script mne_bids.exe is installed in 'C:\Users\irmak\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Requirement already satisfied: mne-bids[full] in c:\users\irmak\appdata\roaming\python\python39\site-packages (0.10)
# Requirement already satisfied: jinja2 in c:\users\irmak\anaconda3\lib\site-packages (from mne-bids[full]) (2.11.3)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\irmak\anaconda3\lib\site-packages (from mne-bids[full]) (1.7.3)
# Requirement already satisfied: mne>=0.24 in c:\users\irmak\anaconda3\lib\site-packages (from mne-bids[full]) (1.0.3)
# Requirement already satisfied: importlib-resources in c:\users\irmak\appdata\roaming\python\python39\site-packages (from mne-bids[full]) (5.9.0)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\irmak\anaconda3\lib\site-packages (from mne-bids[full]) (1.21.5)
# Requirement already satisfied: setuptools in c:\users\irmak\anaconda3\lib\site-packages (from mne-bids[full]) (61.2.0)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\irmak\anaconda3\lib\site-packages (from mne-bids[full]) (1.4.2)
# Requirement already satisfied: pybv>=0.6 in c:\users\irmak\appdata\roaming\python\python39\site-packages (from mne-bids[full]) (0.7.4)
# Requirement already satisfied: EDFlib-Python>=1.0.6 in c:\users\irmak\appdata\roaming\python\python39\site-packages (from mne-bids[full]) (1.0.6)
# Requirement already satisfied: matplotlib>=3.1.0 in c:\users\irmak\anaconda3\lib\site-packages (from mne-bids[full]) (3.5.1)
# Requirement already satisfied: nibabel>=2.5 in c:\users\irmak\appdata\roaming\python\python39\site-packages (from mne-bids[full]) (4.0.1)
# Requirement already satisfied: pymatreader>=0.0.29 in c:\users\irmak\appdata\roaming\python\python39\site-packages (from mne-bids[full]) (0.0.30)
# Requirement already satisfied: cycler>=0.10 in c:\users\irmak\anaconda3\lib\site-packages (from matplotlib>=3.1.0->mne-bids[full]) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\irmak\anaconda3\lib\site-packages (from matplotlib>=3.1.0->mne-bids[full]) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\irmak\anaconda3\lib\site-packages (from matplotlib>=3.1.0->mne-bids[full]) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\irmak\anaconda3\lib\site-packages (from matplotlib>=3.1.0->mne-bids[full]) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\irmak\anaconda3\lib\site-packages (from matplotlib>=3.1.0->mne-bids[full]) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\irmak\anaconda3\lib\site-packages (from matplotlib>=3.1.0->mne-bids[full]) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\irmak\anaconda3\lib\site-packages (from matplotlib>=3.1.0->mne-bids[full]) (4.25.0)
# Requirement already satisfied: pooch>=1.5 in c:\users\irmak\anaconda3\lib\site-packages (from mne>=0.24->mne-bids[full]) (1.6.0)
# Requirement already satisfied: tqdm in c:\users\irmak\anaconda3\lib\site-packages (from mne>=0.24->mne-bids[full]) (4.64.0)
# Requirement already satisfied: decorator in c:\users\irmak\anaconda3\lib\site-packages (from mne>=0.24->mne-bids[full]) (5.1.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\irmak\anaconda3\lib\site-packages (from pandas>=0.24.0->mne-bids[full]) (2021.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\irmak\anaconda3\lib\site-packages (from pooch>=1.5->mne>=0.24->mne-bids[full]) (2.27.1)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\irmak\anaconda3\lib\site-packages (from pooch>=1.5->mne>=0.24->mne-bids[full]) (1.4.4)
# Requirement already satisfied: xmltodict in c:\users\irmak\appdata\roaming\python\python39\site-packages (from pymatreader>=0.0.29->mne-bids[full]) (0.13.0)
# Requirement already satisfied: h5py in c:\users\irmak\anaconda3\lib\site-packages (from pymatreader>=0.0.29->mne-bids[full]) (3.6.0)
# Requirement already satisfied: future in c:\users\irmak\anaconda3\lib\site-packages (from pymatreader>=0.0.29->mne-bids[full]) (0.18.2)
# Requirement already satisfied: six>=1.5 in c:\users\irmak\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.0->mne-bids[full]) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\irmak\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne>=0.24->mne-bids[full]) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\irmak\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne>=0.24->mne-bids[full]) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\irmak\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne>=0.24->mne-bids[full]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\irmak\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne>=0.24->mne-bids[full]) (3.3)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\irmak\anaconda3\lib\site-packages (from importlib-resources->mne-bids[full]) (3.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\irmak\anaconda3\lib\site-packages (from jinja2->mne-bids[full]) (2.0.1)
# Requirement already satisfied: colorama in c:\users\irmak\anaconda3\lib\site-packages (from tqdm->mne>=0.24->mne-bids[full]) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from mne_bids.copyfiles import copyfile_brainvision
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 from mne_bids.copyfiles import copyfile_brainvision
#
# ModuleNotFoundError: No module named 'mne_bids'

# %%
import numpy as np

# %%
import urllib.request

# %%
import matplotlib.pyplot as plt

# %%
print("Import BrainVisionData")
# Out:
# Import BrainVisionData

# %%
# %matplotlib qt

# %%
raw = mne.io.read_raw_brainvision('eeg-sample\sub-010012.vhdr', eog=('HEOGL', 'HEOGR', 'VEOGb'), misc='auto', scale=1.0, preload=True, verbose=None)
# Out:
# Extracting parameters from eeg-sample\sub-010012.vhdr...
# Setting channel info structure...
# Reading 0 ... 2614449  =      0.000 ...  1045.780 secs...

# %%
raw.plot()
# Out:
# Opening raw-browser...
# <MNEBrowseFigure size 800x800 with 4 Axes>
# Closing raw-browser...
# Channels marked as bad:
# none

# %%
raw.info['subject_info']= {'id':2, 'hand':2,'sex':0}
#to change subject info
# Out:
# Closing raw-browser...
# Channels marked as bad:
# ['FC2', 'F7']

# %%
raw.info
# Out:
# <Info | 9 non-empty values
#  bads: 1 items (Fz)
#  ch_names: Fp1, Fp2, F7, F3, Fz, F4, F8, FC5, FC1, FC2, FC6, T7, C3, Cz, ...
#  chs: 62 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 1000.0 Hz
#  meas_date: 2013-11-11 15:46:49 UTC
#  nchan: 62
#  projs: []
#  sfreq: 2500.0 Hz
#  subject_info: 3 items (dict)
# >

# %%
print("Set EOG channels")
# Out:
# Set EOG channels

# %%
raw.set_channel_types({'VEOG': 'eog'})
# Out:
# <RawBrainVision | sub-010012.eeg, 62 x 2614450 (1045.8 s), ~67 kB, data not loaded>

# %%
raw.info['ch_names']
# Out:
# ['Fp1',
#  'Fp2',
#  'F7',
#  'F3',
#  'Fz',
#  'F4',
#  'F8',
#  'FC5',
#  'FC1',
#  'FC2',
#  'FC6',
#  'T7',
#  'C3',
#  'Cz',
#  'C4',
#  'T8',
#  'VEOG',
#  'CP5',
#  'CP1',
#  'CP2',
#  'CP6',
#  'AFz',
#  'P7',
#  'P3',
#  'Pz',
#  'P4',
#  'P8',
#  'PO9',
#  'O1',
#  'Oz',
#  'O2',
#  'PO10',
#  'AF7',
#  'AF3',
#  'AF4',
#  'AF8',
#  'F5',
#  'F1',
#  'F2',
#  'F6',
#  'FT7',
#  'FC3',
#  'FC4',
#  'FT8',
#  'C5',
#  'C1',
#  'C2',
#  'C6',
#  'TP7',
#  'CP3',
#  'CPz',
#  'CP4',
#  'TP8',
#  'P5',
#  'P1',
#  'P2',
#  'P6',
#  'PO7',
#  'PO3',
#  'POz',
#  'PO4',
#  'PO8']

# %%
raw.set_montage('standard_1005')
#biosemi64 etc
# Out:
# <RawBrainVision | sub-010012.eeg, 62 x 2614450 (1045.8 s), ~91 kB, data not loaded>

# %%
raw.plot_sensors(show_names=True);

# %%
print("Identification and removal of electrodes and sensors")
# Out:
# Identification and removal of electrodes and sensors

# %%
# %matplotlib notebook
raw.plot(scalings='auto', highpass=1, lowpass=30);
# Out:
# Warning: Cannot change to a different GUI toolkit: notebook. Using qt instead.
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# Opening raw-browser...

# %%
print("Remove bad channels")
# Out:
# Remove bad channels

# %%
raw.info['bads'] = ['T7','C6']

# %%
raw
# Out:
# <RawBrainVision | sub-010012.eeg, 62 x 2614450 (1045.8 s), ~91 kB, data not loaded>
# Closing raw-browser...
# Channels marked as bad:
# ['Fz']

# %%
print('Downsampling')
# Out:
# Downsampling

# %%
raw.info['sfreq']
# Out:
# 2500.0

# %%
raw.resample(500) 

#new sampling rate
# Out:
# <RawBrainVision | sub-010012.eeg, 62 x 522890 (1045.8 s), ~247.4 MB, data loaded>

# %%
print('Filtering')

# %%
raw.filter(1.,30., phase='zero-double')
raw.plot()
raw

# %%
print('Additional removal of physiological artifacts-ICA')

# %%
from mne.preprocessing import ICA

ica = ICA(n_components=24, method='infomax', random_state=42)
ica.fit(raw, decim=10)
# Out:
# Fitting ICA to data using 62 channels (please be patient, this may take a while)
# Omitting 4809 of 2614450 (0.18%) samples, retaining 2609641 (99.82%) samples.
# Selecting by number: 24 components
# C:\Users\irmak\anaconda3\lib\site-packages\mne\preprocessing\infomax_.py:192: RuntimeWarning: overflow encountered in exp
#   y = 1.0 / (1.0 + np.exp(-u))
# Fitting ICA took 124.7s.
# <ICA | raw data decomposition, method: infomax (fit in 500 iterations on 260965 samples), 24 ICA components explaining 99.3 % of variance (62 PCA components available), channel types: eeg, no sources marked for exclusion>

# %%
ica.plot_components();
# Out:
# WARNING:root:Did not find any electrode locations (in the info object), will attempt to use digitization points instead. However, if digitization points do not correspond to the EEG electrodes, this will lead to bad results. Please verify that the sensor locations in the plot are accurate.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 ica.plot_components()
#
# File ~\anaconda3\lib\site-packages\mne\preprocessing\ica.py:1935, in ICA.plot_components(self, picks, ch_type, res, vmin, vmax, cmap, sensors, colorbar, title, show, outlines, contours, image_interp, inst, plot_std, topomap_args, image_args, psd_args, reject, sphere, verbose)
#    1927 @copy_function_doc_to_method_doc(plot_ica_components)
#    1928 def plot_components(self, picks=None, ch_type=None, res=64,
#    1929                     vmin=None, vmax=None, cmap='RdBu_r', sensors=True,
#    (...)
#    1933                     image_args=None, psd_args=None, reject='auto',
#    1934                     sphere=None, verbose=None):
# -> 1935     return plot_ica_components(self, picks=picks, ch_type=ch_type,
#    1936                                res=res, vmin=vmin,
#    1937                                vmax=vmax, cmap=cmap, sensors=sensors,
#    1938                                colorbar=colorbar, title=title, show=show,
#    1939                                outlines=outlines, contours=contours,
#    1940                                image_interp=image_interp,
#    1941                                inst=inst, plot_std=plot_std,
#    1942                                topomap_args=topomap_args,
#    1943                                image_args=image_args, psd_args=psd_args,
#    1944                                reject=reject, sphere=sphere,
#    1945                                verbose=verbose)
#
# File <decorator-gen-167>:12, in plot_ica_components(ica, picks, ch_type, res, vmin, vmax, cmap, sensors, colorbar, title, show, outlines, contours, image_interp, inst, plot_std, topomap_args, image_args, psd_args, reject, sphere, verbose)
#
# File ~\anaconda3\lib\site-packages\mne\viz\topomap.py:1197, in plot_ica_components(ica, picks, ch_type, res, vmin, vmax, cmap, sensors, colorbar, title, show, outlines, contours, image_interp, inst, plot_std, topomap_args, image_args, psd_args, reject, sphere, verbose)
#    1195 for k in range(0, n_components, p):
#    1196     picks = range(k, min(k + p, n_components))
# -> 1197     fig = plot_ica_components(
#    1198         ica, picks=picks, ch_type=ch_type, res=res, vmax=vmax,
#    1199         cmap=cmap, sensors=sensors, colorbar=colorbar, title=title,
#    1200         show=show, outlines=outlines, contours=contours,
#    1201         image_interp=image_interp, inst=inst, plot_std=plot_std,
#    1202         topomap_args=topomap_args, image_args=image_args,
#    1203         psd_args=psd_args, reject=reject, sphere=sphere)
#    1204     figs.append(fig)
#    1205 return figs
#
# File <decorator-gen-167>:12, in plot_ica_components(ica, picks, ch_type, res, vmin, vmax, cmap, sensors, colorbar, title, show, outlines, contours, image_interp, inst, plot_std, topomap_args, image_args, psd_args, reject, sphere, verbose)
#
# File ~\anaconda3\lib\site-packages\mne\viz\topomap.py:1215, in plot_ica_components(ica, picks, ch_type, res, vmin, vmax, cmap, sensors, colorbar, title, show, outlines, contours, image_interp, inst, plot_std, topomap_args, image_args, psd_args, reject, sphere, verbose)
#    1210 cmap = _setup_cmap(cmap, n_axes=len(picks))
#    1211 data = np.dot(ica.mixing_matrix_[:, picks].T,
#    1212               ica.pca_components_[:ica.n_components_])
#    1214 data_picks, pos, merge_channels, names, ch_type, sphere, clip_origin = \
# -> 1215     _prepare_topomap_plot(ica, ch_type, sphere=sphere)
#    1216 outlines = _make_head_outlines(sphere, pos, outlines, clip_origin)
#    1218 data = np.atleast_2d(data)
#
# File ~\anaconda3\lib\site-packages\mne\viz\topomap.py:84, in _prepare_topomap_plot(inst, ch_type, sphere)
#      81 info._check_consistency()
#      83 # special case for merging grad channels
# ---> 84 layout = find_layout(info)
#      85 if (ch_type == 'grad' and layout is not None and
#      86         (layout.kind.startswith('Vectorview') or
#      87          layout.kind.startswith('Neuromag_122'))):
#      88     picks, _ = _pair_grad_sensors(info, layout)
#
# File ~\anaconda3\lib\site-packages\mne\channels\layout.py:426, in find_layout(info, ch_type, exclude)
#     423     if not isinstance(info, (dict, Info)):
#     424         raise RuntimeError('Cannot make EEG layout, no measurement info '
#     425                            'was passed to `find_layout`')
# --> 426     return make_eeg_layout(info, exclude=exclude)
#     427 elif has_csd_coils and ch_type in [None, 'csd']:
#     428     return make_eeg_layout(info, exclude=exclude, csd=True)
#
# File ~\anaconda3\lib\site-packages\mne\channels\layout.py:262, in make_eeg_layout(info, radius, width, height, exclude, csd)
#     260     pick_kwargs.update(csd=True, eeg=False)
#     261 picks = pick_types(info, **pick_kwargs)
# --> 262 loc2d = _find_topomap_coords(info, picks)
#     263 names = [info['chs'][i]['ch_name'] for i in picks]
#     265 # Scale [x, y] to be in the range [-0.5, 0.5]
#     266 # Don't mess with the origin or aspect ratio
#
# File ~\anaconda3\lib\site-packages\mne\channels\layout.py:625, in _find_topomap_coords(info, picks, layout, ignore_overlap, to_sphere, sphere)
#     623     pos = np.asarray(pos)
#     624 else:
# --> 625     pos = _auto_topomap_coords(
#     626         info, picks, ignore_overlap=ignore_overlap, to_sphere=to_sphere,
#     627         sphere=sphere)
#     629 return pos
#
# File ~\anaconda3\lib\site-packages\mne\channels\layout.py:690, in _auto_topomap_coords(info, picks, ignore_overlap, to_sphere, sphere)
#     688 # Get EEG digitization points
#     689 if info['dig'] is None or len(info['dig']) == 0:
# --> 690     raise RuntimeError('No digitization points found.')
#     692 locs3d = np.array([point['r'] for point in info['dig']
#     693                    if point['kind'] == FIFF.FIFFV_POINT_EEG])
#     695 if len(locs3d) == 0:
#
# RuntimeError: No digitization points found.

# %%
ica.plot_sources(raw, 0);

# %%
ica.plot_properties(raw, 0);

# %%
ica.plot_properties(raw, 2);

# %%
ica.exclude = [0,9]

# %%
print('Interpolate Bad Channels')

# %%
raw_ica= ica.apply(raw)
raw_ica.plot();

# %%
raw_ica.interpolate_bads()

# %%
raw.plot();

# %%
print('Data Segmentation')

# %%
events_from_annot, event_dict = mne.events_from_annotations(raw_ica)

# %%
events_from_annot
# Out:
# array([[     0,      0,  99999],
#        [     0,      0,  10001],
#        [  2010,      0,      1],
#        ...,
#        [516984,      0,    200],
#        [517984,      0,    200],
#        [518984,      0,    200]])

# %%
epochs = mne.Epochs(raw_ica, events_from_annot, event_id=event_dict, tmin=0, tmax=2, baseline=(0, 0), event_repeated='drop', preload=True)
#TMax min 1 sec before and after

# %%
epochs.plot()
# Out:
# Opening epochs-browser...
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">

# %%
print('Rereference')
# Out:
# Rereference

# %%
epochs.set_eeg_reference(ref_channels='average')
#for reference change it to average
# Out:
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# <Epochs |  498 events (all good), 0 - 2 sec, baseline 0 – 0 sec, ~235.9 MB, data loaded,
#  'New Segment/': 1
#  'Stimulus/S  1': 17
#  'Stimulus/S200': 240
#  'Stimulus/S210': 240>

# %%
epochs['Stimulus/S200'].plot_psd(fmin=0, fmax=30);
#epochs around this trigger
# Out:
# <img src="data:image/png;base64,..." width="1000">
#     Using multitaper spectrum estimation with 7 DPSS windows

# %%
epochs['Stimulus/S210'].plot_psd(fmin=0, fmax=30);
# Out:
# <img src="data:image/png;base64,..." width="1000">
#     Using multitaper spectrum estimation with 7 DPSS windows

# %%
epochs['Stimulus/S200'].average().plot();
# Out:
# <img src="data:image/png;base64,..." width="640">
